# %%
import os, shutil
from google.colab import drive
drive.mount('/content/gdrive') # 표시되는 화면에서 자신이 사용 중인 구글 드라이브를 선택하고 진행
os.chdir('gdrive/My Drive')
# %cd Test/Audio/ # 해당 위치에 본 예제에 사용되는 rain.wav 파일이 존재 (테스트에 사용될 wav 파일을 미리 업로드 해 두어야 함)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Test/Audio

# %%
import librosa, librosa.display
audio_data = 'rain.wav'
x , sr = librosa.load(audio_data, sr=44100)

import matplotlib.pyplot as plt
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
